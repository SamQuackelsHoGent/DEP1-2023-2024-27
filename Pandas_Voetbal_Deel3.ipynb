# %% [markdown]
# # Cleaning up the doelpunten.csv file

# %%
import pandas as pd

# %% [markdown]
# ### Creating a dataframe

# %%
df = pd.read_csv("doelpunten.csv")
columns = ["matchID","seizoen","speeldag","datum","tijdstip","thuisploeg","uitploeg","scorendePloeg","tijdstipDoelpunt","standThuisPloeg","standUitPloeg"]
df.columns = columns

# %%
df.head()
# Out:
#    matchID seizoen  speeldag      datum tijdstip       thuisploeg  \
# 0  4008203   60/61         1  4/09/1960    15:00  St-Truidense VV
# 1  4008204   60/61         1  4/09/1960    15:00  Eendracht Aalst
# 2  4008204   60/61         1  4/09/1960    15:00  Eendracht Aalst
# 3  4008204   60/61         1  4/09/1960    15:00  Eendracht Aalst
# 4  4008204   60/61         1  4/09/1960    15:00  Eendracht Aalst
#
#         uitploeg    scorendePloeg tijdstipDoelpunt  standThuisPloeg  \
# 0  Standard Luik    Standard Luik            15:19                0
# 1     Antwerp FC       Antwerp FC            15:18                0
# 2     Antwerp FC  Eendracht Aalst            15:18                1
# 3     Antwerp FC  Eendracht Aalst            15:26                2
# 4     Antwerp FC       Antwerp FC            15:02                2
#
#    standUitPloeg
# 0              2
# 1              1
# 2              1
# 3              1
# 4              2

# %%
df.tijdstip = pd.to_datetime(df.tijdstip, format='%H:%M')

# %%
for i in range (0, df.shape[0]):
  if len(df.tijdstipDoelpunt[i])!=5:
    df.tijdstipDoelpunt[i] += "0"
  if int(df.tijdstipDoelpunt[i][-2:])>=60:
    minuten = int(df.tijdstipDoelpunt[i][-2:]) - 60
    uur = int(df.tijdstipDoelpunt[i][:-3]) + 1
    tijd = ""
    tijd += str(uur)
    tijd += ":"
    tijd += str(minuten)
    df.tijdstipDoelpunt[i] = tijd
# Out:
# <ipython-input-115-e2ec5448d5c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.tijdstipDoelpunt[i] += "0"

# %%
# for i in range(0, df.shape[0]):
#   print(i, pd.to_datetime(df.tijdstipDoelpunt[i]))


df.tijdstipDoelpunt = pd.to_datetime(df.tijdstipDoelpunt, format='%H:%M')

# %%
df.head()
# Out:
#    matchID seizoen  speeldag      datum            tijdstip       thuisploeg  \
# 0  4008203   60/61         1  4/09/1960 1900-01-01 15:00:00  St-Truidense VV
# 1  4008204   60/61         1  4/09/1960 1900-01-01 15:00:00  Eendracht Aalst
# 2  4008204   60/61         1  4/09/1960 1900-01-01 15:00:00  Eendracht Aalst
# 3  4008204   60/61         1  4/09/1960 1900-01-01 15:00:00  Eendracht Aalst
# 4  4008204   60/61         1  4/09/1960 1900-01-01 15:00:00  Eendracht Aalst
#
#         uitploeg    scorendePloeg    tijdstipDoelpunt  standThuisPloeg  \
# 0  Standard Luik    Standard Luik 1900-01-01 15:19:00                0
# 1     Antwerp FC       Antwerp FC 1900-01-01 15:18:00                0
# 2     Antwerp FC  Eendracht Aalst 1900-01-01 15:18:00                1
# 3     Antwerp FC  Eendracht Aalst 1900-01-01 15:26:00                2
# 4     Antwerp FC       Antwerp FC 1900-01-01 15:02:00                2
#
#    standUitPloeg
# 0              2
# 1              1
# 2              1
# ...
